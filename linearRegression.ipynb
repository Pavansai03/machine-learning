# %% [markdown]
# <a href="https://colab.research.google.com/github/Pavansai03/machine-learning/blob/main/linearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
from sklearn import linear_model

# %%
df = pd.read_csv("hiring.csv")
df
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
# !pip install word2number
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for word2number: filename=word2number-1.1-py3-none-any.whl size=5568 sha256=a007c1f886718ce4fa9d369b1da2f3820ca159c100134cb71d6e72fb89097d3a
#   Stored in directory: /root/.cache/pip/wheels/cd/ef/ae/073b491b14d25e2efafcffca9e16b2ee6d114ec5c643ba4f06
# Successfully built word2number
# ...

# %%
from word2number import w2n

# %%
df.experience = df.experience.fillna("zero")
df
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0       zero                    8.0                           9      50000
# 1       zero                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000

# %%
x = df.iloc[:,1:4]
y =df.iloc[:,-1]
test_score_median = np.median(df['test_score(out of 10)'])
df['test_score(out of 10)'] = df['test_score(out of 10)'].fillna(test_score_median)
reg = linear_model.LinearRegression()
reg.fit(x,y)
x
# Out:
#    experience  test_score(out of 10)  interview_score(out of 10)
# 0           0               8.000000                           9
# 1           0               8.000000                           6
# 2           5               6.000000                           7
# 3           2              10.000000                          10
# 4           7               9.000000                           6
# 5           3               7.000000                          10
# 6          10               7.857143                           7
# 7          11               7.000000                           8

# %%
reg.predict([[12,10,10]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([92268.07227784])

# %%
reg.coef_
# Out:
# array([2827.63404314, 1912.93803053, 2196.9753141 ])

# %%
reg.intercept_
# Out:
# np.float64(17237.330313727172)
